# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd "gdrive/MyDrive/Mini BERT CMU"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Mini BERT CMU

# %%
# !git clone https://github.com/neubig/minbert-assignment.git

# %%
# %cd minbert-assignment
# Out:
# /content/gdrive/MyDrive/Mini BERT CMU/minbert-assignment

# %%
# !pip install torch torchvision torchaudio
# !pip install tqdm
# !pip install requests
# !pip install importlib-metadata
# !pip install filelock
# !pip install sklearn
# !pip install tokenizers
# !pip install explainaboard_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %%bash
# python sanity_check.py
# Out:
# Your BERT implementation is correct!

# %%
# %%bash
# python optimizer_test.py
# Out:
# Optimizer test passed!

# %%
# %%bash
# python classifier.py --use_gpu --batch_size 64 --option pretrain
# Out:
# args: {'train': 'data/cfimdb-train.txt', 'dev': 'data/cfimdb-dev.txt', 'test': 'data/cfimdb-test.txt', 'seed': 11711, 'epochs': 10, 'option': 'pretrain', 'use_gpu': True, 'dev_out': 'cfimdb-dev-output.txt', 'test_out': 'cfimdb-test-output.txt', 'batch_size': 64, 'hidden_dropout_prob': 0.3, 'lr': 1e-05}
# load 1707 data from data/cfimdb-train.txt
# load 245 data from data/cfimdb-dev.txt
# save the model to pretrain-10-1e-05.pt
# epoch 0: train loss :: 0.720, train acc :: 0.501, dev acc :: 0.502
# epoch 1: train loss :: 0.722, train acc :: 0.497, dev acc :: 0.502
# epoch 2: train loss :: 0.703, train acc :: 0.490, dev acc :: 0.473
# epoch 3: train loss :: 0.699, train acc :: 0.481, dev acc :: 0.469
# epoch 4: train loss :: 0.700, train acc :: 0.466, dev acc :: 0.482
# epoch 5: train loss :: 0.708, train acc :: 0.463, dev acc :: 0.482
# epoch 6: train loss :: 0.700, train acc :: 0.476, dev acc :: 0.469
# epoch 7: train loss :: 0.700, train acc :: 0.476, dev acc :: 0.473
# ...

# %%
# %%bash
# python classifier.py --use_gpu --batch_size 16 --option finetune
# Out:
# args: {'train': 'data/cfimdb-train.txt', 'dev': 'data/cfimdb-dev.txt', 'test': 'data/cfimdb-test.txt', 'seed': 11711, 'epochs': 10, 'option': 'finetune', 'use_gpu': True, 'dev_out': 'cfimdb-dev-output.txt', 'test_out': 'cfimdb-test-output.txt', 'batch_size': 8, 'hidden_dropout_prob': 0.3, 'lr': 1e-05}
# load 1707 data from data/cfimdb-train.txt
# load 245 data from data/cfimdb-dev.txt
# save the model to finetune-10-1e-05.pt
# epoch 0: train loss :: 0.419, train acc :: 0.984, dev acc :: 0.951
# save the model to finetune-10-1e-05.pt
# epoch 1: train loss :: 0.076, train acc :: 0.995, dev acc :: 0.955
# save the model to finetune-10-1e-05.pt
# epoch 2: train loss :: 0.033, train acc :: 0.995, dev acc :: 0.959
# epoch 3: train loss :: 0.031, train acc :: 0.987, dev acc :: 0.927
# epoch 4: train loss :: 0.038, train acc :: 0.997, dev acc :: 0.947
# epoch 5: train loss :: 0.020, train acc :: 0.998, dev acc :: 0.943
# epoch 6: train loss :: 0.027, train acc :: 0.998, dev acc :: 0.951
# ...
